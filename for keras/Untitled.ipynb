# %%
from keras.models import Sequential
from keras.layers import Densel
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\users\shaag\appdata\local\programs\python\python37-32\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in swig_import_helper()
#      17         try:
# ---> 18             fp, pathname, description = imp.find_module('_pywrap_tensorflow', [dirname(__file__)])
#      19         except ImportError:
#
# c:\users\shaag\appdata\local\programs\python\python37-32\lib\imp.py in find_module(name, path)
#     295     else:
# --> 296         raise ImportError(_ERR_MSG.format(name), name=name)
#     297
#
# ImportError: No module named '_pywrap_tensorflow'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ...
